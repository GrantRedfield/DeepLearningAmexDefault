# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as snsi
import numpy as np
from pylab import rcParams
import tensorflow as tf
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
from tensorflow import keras
from keras.models import Model, load_model
from keras.layers import Input, Dense, Bidirectional
from tensorflow.keras import layers
from tensorflow.python.client import device_lib
from keras.layers import LSTM 
from keras.callbacks import ModelCheckpoint, TensorBoard
from tensorflow.keras import activations
from keras import regularizers
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, precision_recall_curve
from sklearn.metrics import recall_score, classification_report, auc, roc_curve
from sklearn.metrics import precision_recall_fscore_support, f1_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
import keras_tuner    
import pickle
from bayes_opt import BayesianOptimization
from sklearn.impute import SimpleImputer
from numpy.random import seed
tf.random.set_seed(42)
pd.set_option("display.max_columns", None)
import os
import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "3"
#import pycuda.autoinit
import gc
SEED = 42 #used to help randomly select the data points
DATA_SPLIT_PCT = 0.2
rcParams['figure.figsize'] = 8, 6
LABELS = ["Normal","Break"]
tf.random.set_seed(42)
pd.options.display.max_rows = 400
# Out:
# Num GPUs Available:  1

# %%
gpus = tf.config.list_physical_devices('GPU')

# %%
if gpus:
    for gpu in gpus:
        tf.config.experimental.set_virtual_device_configuration(gpu,[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=10000000)])

# %%
def Data_Split(current_data, number_of_statements):
    unique_customer_ids = current_data.customer_ID.unique()
    grouped = current_data.groupby('customer_ID').size().reset_index(name="count")
    grouped = grouped.query("count == @number_of_statements")
    customer_ids_train, customer_ids_test = train_test_split(unique_customer_ids, test_size=0.3, random_state=42)
    x_train = current_data[(current_data['customer_ID'].isin(customer_ids_train)) & (current_data['customer_ID'].isin(grouped['customer_ID'])) ]
    x_test = current_data[(current_data['customer_ID'].isin(customer_ids_test)) & (current_data['customer_ID'].isin(grouped['customer_ID'])) ]
    y_train = x_train['target']
    y_test = x_test['target']
    
    unique_customer_ids_x_train = x_train.customer_ID.nunique()   
    unique_customer_ids_x_test = x_test.customer_ID.nunique()

    x_train = x_train.drop(columns=['customer_ID', 'S_2', 'RANK','target', 'count'])
    x_test = x_test.drop(columns=['customer_ID', 'S_2', 'RANK','target', 'count'])
    del current_data
    gc.collect()
    return x_train, y_train, x_test, y_test, unique_customer_ids_x_train, unique_customer_ids_x_test

# %%
def setScaler(x_data, x_values_to_scale):
    scaler = StandardScaler()
    scaler.fit(x_data[x_values_to_scale])
    return scaler


def setOneHotEncoder(x_data, categorical_cols):
    transformer = make_column_transformer((OneHotEncoder( handle_unknown='ignore'), 
                                       categorical_cols), remainder='passthrough')
    one_hot_transformer = transformer.fit(x_data)

    with open("C:\\Users\\Grant\\Desktop\\Data_Science\\AMEX\\ENCODERS\\" + str(number_of_statements) + '_encoder', "wb") as f: 
        pickle.dump(one_hot_transformer, f)
    
    return one_hot_transformer

# %%
def TransformData(x_data, y_data, numeric_scaler, numeric_cols, categorical_cols, column_means, one_hot_transformer, unique_customer_ids):

    for col in column_means.columns:
        x_data[col] = x_data[col].fillna(value = column_means[col][0])
    
    x_data[numeric_cols] = numeric_scaler.transform(x_data[numeric_cols])
    x_data[numeric_cols] = x_data[numeric_cols].fillna(0)
    x_data[categorical_cols] = x_data[categorical_cols].fillna('missing')
    x_data[categorical_cols] = x_data[categorical_cols].astype('string')
    x_data[categorical_cols] = x_data[categorical_cols].astype('category')
    

    #print(x_data.isnull().sum())
    
    x_data_only_cats = one_hot_transformer.transform(x_data)
    data_hot_encoded = pd.DataFrame(x_data_only_cats, index=x_data.index)
    #Extract only the columns that didnt need to be encoded
    x_data = x_data.drop(columns=categorical_cols)
    #Concatenate the two dataframes : 
    x_data = pd.concat([data_hot_encoded, x_data], axis=1)
    

    
    #Reshape
    number_of_features = x_data.shape[1]
    x_data = [x_data[c].values.reshape(unique_customer_ids, number_of_statements) for c in x_data.columns] #Change Here
    #full_reshaped_list = tuple(full_reshaped_list)
    x_data = np.hstack(
        (x_data)
    ).reshape(unique_customer_ids, number_of_features, number_of_statements).transpose(0, 2, 1) #Change Here
    
    y_data = y_data[::number_of_statements] #Change Here
    y_data = y_data.to_numpy()
    return x_data, y_data

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))


def amex_metric_mod(y_true: tf.Tensor, y_pred: tf.Tensor) -> float:

    y_true = tf.cast(y_true, dtype=tf.float64)
    y_pred = tf.cast(y_pred, dtype=tf.float64)
    
    labels     = np.transpose(np.array([y_true, y_pred]))
    labels     = labels[labels[:, 1].argsort()[::-1]]
    weights    = np.where(labels[:,0]==0, 20, 1)
    cut_vals   = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four   = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])

    gini = [0,0]
    for i in [1,0]:
        labels         = np.transpose(np.array([y_true, y_pred]))
        labels         = labels[labels[:, i].argsort()[::-1]]
        weight         = np.where(labels[:,0]==0, 20, 1)
        weight_random  = np.cumsum(weight / np.sum(weight))
        total_pos      = np.sum(labels[:, 0] *  weight)
        cum_pos_found  = np.cumsum(labels[:, 0] * weight)
        lorentz        = cum_pos_found / total_pos
        gini[i]        = np.sum((lorentz - weight_random) * weight)

    return 0.5 * (gini[1]/gini[0] + top_four)



def amex_metric_tensorflow(y_true: tf.Tensor, y_pred: tf.Tensor) -> float:

    # convert dtypes to float64
    y_true = tf.cast(y_true, dtype=tf.float64)
    y_pred = tf.cast(y_pred, dtype=tf.float64)

    # count of positives and negatives
    n_pos = tf.math.reduce_sum(y_true)
    n_neg = tf.cast(tf.shape(y_true)[0], dtype=tf.float64) - n_pos

    # sorting by descring prediction values
    indices = tf.argsort(y_pred, axis=0, direction='DESCENDING')
    preds, target = tf.gather(y_pred, indices), tf.gather(y_true, indices)

    # filter the top 4% by cumulative row weights
    weight = 20.0 - target * 19.0
    cum_norm_weight = tf.cumsum(weight / tf.reduce_sum(weight))
    four_pct_filter = cum_norm_weight <= 0.04

    # default rate captured at 4%
    d = tf.reduce_sum(target[four_pct_filter]) / n_pos

    # weighted gini coefficient
    lorentz = tf.cumsum(target / n_pos)
    gini = tf.reduce_sum((lorentz - cum_norm_weight) * weight)

    # max weighted gini coefficient
    gini_max = 10 * n_neg * (1 - 19 / (n_pos + 20 * n_neg))

    # normalized weighted gini coefficient
    g = gini / gini_max

    return 0.5 * (g + d)

# %%
def Build_Model(x_train, y_train, x_test,y_test,number_of_statements):
    number_of_features = x_train.shape[2]
    num_units = x_train.shape[0]
    if num_units > 4000:
        num_units = 4000
    
    num_neurons = number_of_features
    model = keras.Sequential()
    model.add(LSTM(units=num_units, activation='relu',return_sequences = True,input_shape=(number_of_statements, number_of_features)))
    model.add(LSTM(units=num_units, return_sequences = True,activation='relu',input_shape=(number_of_statements, number_of_features)))
    model.add(LSTM(units=num_units, activation='relu',input_shape=(number_of_statements, number_of_features)))
    #model.add(tf.keras.layers.Dropout(recurrent_dropout))
    model.add(layers.Dense(num_neurons, activation = 'relu'))
    model.add(layers.Dense(num_neurons/4, activation = 'relu'))
    model.add(layers.Dense(1, activation = 'sigmoid'))
        
    epochs = 30
    batch_size = 32

    callbacks = [
        keras.callbacks.ModelCheckpoint(
            "D:\\AMEX\\best_model" + str(number_of_statements) + "_Statements.h5", save_best_only=True, monitor="val_amex_metric_tensorflow"
        ),
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
        ),
        keras.callbacks.EarlyStopping(monitor='val_accuracy',  
                   patience=5)
    ]
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(
          optimizer=optimizer,
            loss='binary_crossentropy',
                  metrics=['accuracy',f1_m,precision_m, recall_m, amex_metric_tensorflow],
        )


    default_model = model.fit(
        x_train,
        y_train,
        batch_size=batch_size,
        epochs=epochs,
        validation_data = (x_test,y_test),
        callbacks=callbacks,
        verbose=1,
    )
    
    del default_model
    del model
    gc.collect()

# %% [markdown]
# # Run PreProcessing

# %%
#Column Definitions
column_means = pd.read_csv("C:\\Users\\Grant\\Desktop\\Data_Science\\AMEX\\AMEX_COLUMN_MEANS.csv")
category_column = ['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_63', 'D_64', 'D_66', 'D_68']

# %%
for number_of_statements in range(1,13):
    print("Processing: File With", number_of_statements, "Statements")
    current_data = pd.read_csv("C:\\Users\\Grant\\Desktop\\Data_Science\\AMEX\\Balanced_Datasets\\balanced_train_"+str(number_of_statements) + "_statement.csv")
    x_train, y_train, x_test, y_test, unique_customer_ids_x_train, unique_customer_ids_x_test = Data_Split(current_data, number_of_statements)

    #Numeric columns
    numeric_columns = x_train.select_dtypes(include=['number','float64']).columns
    numeric_cols = x_train.columns
    x_values_to_scale= [x for x in numeric_cols if x not in category_column]

    numeric_scaler = setScaler(x_train, x_values_to_scale)
    one_hot_encoder = setOneHotEncoder(x_train, category_column)

    x_train, y_train = TransformData(x_train, y_train, numeric_scaler, x_values_to_scale, category_column, column_means, one_hot_encoder, unique_customer_ids_x_train)
    x_test, y_test = TransformData(x_test, y_test, numeric_scaler, x_values_to_scale, category_column, column_means, one_hot_encoder, unique_customer_ids_x_test)
    
    Build_Model(x_train,y_train,x_test ,y_test,number_of_statements)
# Out:
# Processing: File With 1 Statements
# C:\Users\Grant\anaconda3\lib\site-packages\sklearn\utils\extmath.py:847: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Grant\anaconda3\lib\site-packages\sklearn\utils\extmath.py:689: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = op(x, *args, **kwargs)
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_1 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_2 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 113/113 [==============================] - 38s 297ms/step - loss: 0.4797 - accuracy: 0.7549 - f1_m: 0.4616 - precision_m: 0.5959 - recall_m: 0.4213 - amex_metric_tensorflow: 0.5587 - val_loss: 0.4103 - val_accuracy: 0.7956 - val_f1_m: 0.6536 - val_precision_m: 0.7709 - val_recall_m: 0.5943 - val_amex_metric_tensorflow: 0.5730 - lr: 1.0000e-04
# Epoch 2/30
# 113/113 [==============================] - 13s 114ms/step - loss: 0.3805 - accuracy: 0.8161 - f1_m: 0.6800 - precision_m: 0.7760 - recall_m: 0.6409 - amex_metric_tensorflow: nan - val_loss: 0.4037 - val_accuracy: 0.8027 - val_f1_m: 0.6711 - val_precision_m: 0.7743 - val_recall_m: 0.6182 - val_amex_metric_tensorflow: 0.5779 - lr: 1.0000e-04
# Epoch 3/30
# 113/113 [==============================] - 13s 113ms/step - loss: 0.3603 - accuracy: 0.8280 - f1_m: 0.7113 - precision_m: 0.7869 - recall_m: 0.6740 - amex_metric_tensorflow: 0.6497 - val_loss: 0.4063 - val_accuracy: 0.8047 - val_f1_m: 0.6853 - val_precision_m: 0.7576 - val_recall_m: 0.6516 - val_amex_metric_tensorflow: 0.5919 - lr: 1.0000e-04
# Epoch 4/30
# 113/113 [==============================] - 13s 113ms/step - loss: 0.3484 - accuracy: 0.8361 - f1_m: 0.7156 - precision_m: 0.7936 - recall_m: 0.6710 - amex_metric_tensorflow: 0.6523 - val_loss: 0.4144 - val_accuracy: 0.7988 - val_f1_m: 0.6540 - val_precision_m: 0.7853 - val_recall_m: 0.5884 - val_amex_metric_tensorflow: 0.5939 - lr: 1.0000e-04
# Epoch 5/30
# 113/113 [==============================] - 13s 113ms/step - loss: 0.3361 - accuracy: 0.8377 - f1_m: 0.7134 - precision_m: 0.7795 - recall_m: 0.6811 - amex_metric_tensorflow: 0.6698 - val_loss: 0.4110 - val_accuracy: 0.8021 - val_f1_m: 0.6929 - val_precision_m: 0.7309 - val_recall_m: 0.6931 - val_amex_metric_tensorflow: 0.5892 - lr: 1.0000e-04
# Epoch 6/30
# 113/113 [==============================] - 13s 114ms/step - loss: 0.3352 - accuracy: 0.8400 - f1_m: 0.7223 - precision_m: 0.7934 - recall_m: 0.6920 - amex_metric_tensorflow: 0.6868 - val_loss: 0.4287 - val_accuracy: 0.7924 - val_f1_m: 0.6672 - val_precision_m: 0.7296 - val_recall_m: 0.6482 - val_amex_metric_tensorflow: 0.5810 - lr: 1.0000e-04
# Epoch 7/30
# 113/113 [==============================] - 13s 114ms/step - loss: 0.3158 - accuracy: 0.8458 - f1_m: 0.7430 - precision_m: 0.8053 - recall_m: 0.7066 - amex_metric_tensorflow: 0.7051 - val_loss: 0.4574 - val_accuracy: 0.8014 - val_f1_m: 0.6856 - val_precision_m: 0.7416 - val_recall_m: 0.6708 - val_amex_metric_tensorflow: 0.5907 - lr: 1.0000e-04
# Epoch 8/30
# 113/113 [==============================] - 13s 114ms/step - loss: 0.2970 - accuracy: 0.8575 - f1_m: 0.7579 - precision_m: 0.8061 - recall_m: 0.7324 - amex_metric_tensorflow: 0.7249 - val_loss: 0.4721 - val_accuracy: 0.8047 - val_f1_m: 0.6901 - val_precision_m: 0.7466 - val_recall_m: 0.6740 - val_amex_metric_tensorflow: 0.5954 - lr: 1.0000e-04
# Processing: File With 2 Statements
# C:\Users\Grant\anaconda3\lib\site-packages\sklearn\utils\extmath.py:847: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Grant\anaconda3\lib\site-packages\sklearn\utils\extmath.py:689: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = op(x, *args, **kwargs)
# WARNING:tensorflow:Layer lstm_3 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_4 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_5 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 135/135 [==============================] - 54s 373ms/step - loss: 0.4665 - accuracy: 0.7728 - f1_m: 0.5221 - precision_m: 0.6106 - recall_m: 0.5140 - amex_metric_tensorflow: 0.5061 - val_loss: 0.4290 - val_accuracy: 0.8018 - val_f1_m: 0.6841 - val_precision_m: 0.7050 - val_recall_m: 0.6879 - val_amex_metric_tensorflow: 0.5490 - lr: 1.0000e-04
# Epoch 2/30
# 135/135 [==============================] - 25s 184ms/step - loss: 0.3853 - accuracy: 0.8184 - f1_m: 0.6969 - precision_m: 0.7391 - recall_m: 0.7008 - amex_metric_tensorflow: 0.6059 - val_loss: 0.4133 - val_accuracy: 0.8073 - val_f1_m: 0.6934 - val_precision_m: 0.7069 - val_recall_m: 0.7010 - val_amex_metric_tensorflow: 0.5596 - lr: 1.0000e-04
# Epoch 3/30
# 135/135 [==============================] - 25s 183ms/step - loss: 0.3620 - accuracy: 0.8265 - f1_m: 0.7063 - precision_m: 0.7472 - recall_m: 0.6963 - amex_metric_tensorflow: 0.6294 - val_loss: 0.4027 - val_accuracy: 0.8062 - val_f1_m: 0.7051 - val_precision_m: 0.6958 - val_recall_m: 0.7355 - val_amex_metric_tensorflow: 0.5654 - lr: 1.0000e-04
# Epoch 4/30
# 135/135 [==============================] - 25s 184ms/step - loss: 0.3441 - accuracy: 0.8407 - f1_m: 0.7333 - precision_m: 0.7644 - recall_m: 0.7301 - amex_metric_tensorflow: 0.6567 - val_loss: 0.4307 - val_accuracy: 0.8067 - val_f1_m: 0.6907 - val_precision_m: 0.7030 - val_recall_m: 0.6930 - val_amex_metric_tensorflow: 0.5667 - lr: 1.0000e-04
# Epoch 5/30
# 135/135 [==============================] - 25s 184ms/step - loss: 0.3215 - accuracy: 0.8459 - f1_m: 0.7371 - precision_m: 0.7632 - recall_m: 0.7322 - amex_metric_tensorflow: 0.6867 - val_loss: 2.8435 - val_accuracy: 0.8008 - val_f1_m: 0.6850 - val_precision_m: 0.6970 - val_recall_m: 0.6946 - val_amex_metric_tensorflow: 0.5638 - lr: 1.0000e-04
# Epoch 6/30
# 135/135 [==============================] - 25s 184ms/step - loss: 0.3118 - accuracy: 0.8612 - f1_m: 0.7562 - precision_m: 0.8058 - recall_m: 0.7426 - amex_metric_tensorflow: 0.7154 - val_loss: 0.4301 - val_accuracy: 0.8078 - val_f1_m: 0.6894 - val_precision_m: 0.7208 - val_recall_m: 0.6805 - val_amex_metric_tensorflow: 0.5651 - lr: 1.0000e-04
# Epoch 7/30
# 135/135 [==============================] - 49s 367ms/step - loss: 0.2968 - accuracy: 0.8705 - f1_m: 0.7785 - precision_m: 0.8208 - recall_m: 0.7628 - amex_metric_tensorflow: 0.7510 - val_loss: 1.1408 - val_accuracy: 0.7997 - val_f1_m: 0.6836 - val_precision_m: 0.6956 - val_recall_m: 0.6894 - val_amex_metric_tensorflow: 0.5481 - lr: 1.0000e-04
# Epoch 8/30
# 135/135 [==============================] - 49s 368ms/step - loss: 0.2560 - accuracy: 0.8924 - f1_m: 0.8216 - precision_m: 0.8539 - recall_m: 0.8082 - amex_metric_tensorflow: 0.7997 - val_loss: 1.1462 - val_accuracy: 0.8008 - val_f1_m: 0.6756 - val_precision_m: 0.7011 - val_recall_m: 0.6674 - val_amex_metric_tensorflow: 0.5424 - lr: 1.0000e-04
# Epoch 9/30
# 135/135 [==============================] - 50s 373ms/step - loss: 0.2178 - accuracy: 0.9031 - f1_m: 0.8372 - precision_m: 0.8697 - recall_m: 0.8263 - amex_metric_tensorflow: 0.8297 - val_loss: 2.2602 - val_accuracy: 0.7856 - val_f1_m: 0.6825 - val_precision_m: 0.6463 - val_recall_m: 0.7380 - val_amex_metric_tensorflow: 0.5293 - lr: 1.0000e-04
# Epoch 10/30
# 135/135 [==============================] - 50s 370ms/step - loss: 0.1791 - accuracy: 0.9267 - f1_m: 0.8746 - precision_m: 0.8959 - recall_m: 0.8674 - amex_metric_tensorflow: 0.8777 - val_loss: 0.7780 - val_accuracy: 0.7861 - val_f1_m: 0.5848 - val_precision_m: 0.7489 - val_recall_m: 0.4976 - val_amex_metric_tensorflow: 0.5039 - lr: 1.0000e-04
# Epoch 11/30
# 135/135 [==============================] - 25s 185ms/step - loss: 0.1612 - accuracy: 0.9348 - f1_m: 0.8905 - precision_m: 0.9088 - recall_m: 0.8876 - amex_metric_tensorflow: 0.9017 - val_loss: 0.9123 - val_accuracy: 0.7975 - val_f1_m: 0.6586 - val_precision_m: 0.7198 - val_recall_m: 0.6257 - val_amex_metric_tensorflow: 0.5159 - lr: 1.0000e-04
# Processing: File With 3 Statements
# WARNING:tensorflow:Layer lstm_6 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_7 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_8 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 128/128 [==============================] - 59s 436ms/step - loss: 0.5515 - accuracy: 0.7064 - f1_m: 0.4350 - precision_m: 0.4965 - recall_m: 0.4762 - amex_metric_tensorflow: 0.5212 - val_loss: 0.4016 - val_accuracy: 0.8093 - val_f1_m: 0.7171 - val_precision_m: 0.7740 - val_recall_m: 0.6870 - val_amex_metric_tensorflow: 0.5749 - lr: 1.0000e-04
# Epoch 2/30
# 128/128 [==============================] - 31s 238ms/step - loss: 0.4170 - accuracy: 0.7979 - f1_m: 0.6998 - precision_m: 0.7479 - recall_m: 0.7132 - amex_metric_tensorflow: 0.5987 - val_loss: 0.4174 - val_accuracy: 0.7950 - val_f1_m: 0.6580 - val_precision_m: 0.8302 - val_recall_m: 0.5625 - val_amex_metric_tensorflow: 0.6019 - lr: 1.0000e-04
# Epoch 3/30
# 128/128 [==============================] - 31s 242ms/step - loss: 0.3955 - accuracy: 0.8053 - f1_m: 0.7092 - precision_m: 0.7516 - recall_m: 0.7304 - amex_metric_tensorflow: 0.6249 - val_loss: 0.3817 - val_accuracy: 0.8207 - val_f1_m: 0.7683 - val_precision_m: 0.7185 - val_recall_m: 0.8395 - val_amex_metric_tensorflow: 0.6110 - lr: 1.0000e-04
# Epoch 4/30
# 128/128 [==============================] - 30s 235ms/step - loss: 0.3701 - accuracy: 0.8249 - f1_m: 0.7483 - precision_m: 0.7576 - recall_m: 0.7675 - amex_metric_tensorflow: 0.6420 - val_loss: 0.4092 - val_accuracy: 0.8116 - val_f1_m: 0.6950 - val_precision_m: 0.8232 - val_recall_m: 0.6219 - val_amex_metric_tensorflow: 0.6221 - lr: 1.0000e-04
# Epoch 5/30
# 128/128 [==============================] - 30s 238ms/step - loss: 0.3642 - accuracy: 0.8286 - f1_m: 0.7500 - precision_m: 0.7695 - recall_m: 0.7611 - amex_metric_tensorflow: 0.6432 - val_loss: 0.4300 - val_accuracy: 0.7887 - val_f1_m: 0.7534 - val_precision_m: 0.6486 - val_recall_m: 0.9196 - val_amex_metric_tensorflow: 0.6167 - lr: 1.0000e-04
# Epoch 6/30
# 128/128 [==============================] - 30s 237ms/step - loss: 0.3642 - accuracy: 0.8262 - f1_m: 0.7539 - precision_m: 0.7659 - recall_m: 0.7827 - amex_metric_tensorflow: 0.6472 - val_loss: 0.3846 - val_accuracy: 0.8333 - val_f1_m: 0.7757 - val_precision_m: 0.7496 - val_recall_m: 0.8200 - val_amex_metric_tensorflow: 0.6290 - lr: 1.0000e-04
# Epoch 7/30
# 128/128 [==============================] - 30s 237ms/step - loss: 0.3543 - accuracy: 0.8323 - f1_m: 0.7489 - precision_m: 0.7765 - recall_m: 0.7574 - amex_metric_tensorflow: 0.6680 - val_loss: 0.3724 - val_accuracy: 0.8305 - val_f1_m: 0.7654 - val_precision_m: 0.7557 - val_recall_m: 0.7903 - val_amex_metric_tensorflow: 0.6366 - lr: 1.0000e-04
# Epoch 8/30
# 128/128 [==============================] - 30s 238ms/step - loss: 0.3505 - accuracy: 0.8328 - f1_m: 0.7530 - precision_m: 0.7691 - recall_m: 0.7728 - amex_metric_tensorflow: 0.6664 - val_loss: 0.3716 - val_accuracy: 0.8282 - val_f1_m: 0.7723 - val_precision_m: 0.7290 - val_recall_m: 0.8361 - val_amex_metric_tensorflow: 0.6367 - lr: 1.0000e-04
# Epoch 9/30
# 128/128 [==============================] - 30s 238ms/step - loss: 0.3563 - accuracy: 0.8345 - f1_m: 0.7628 - precision_m: 0.7799 - recall_m: 0.7772 - amex_metric_tensorflow: 0.6728 - val_loss: 0.3712 - val_accuracy: 0.8259 - val_f1_m: 0.7601 - val_precision_m: 0.7461 - val_recall_m: 0.7896 - val_amex_metric_tensorflow: 0.6338 - lr: 1.0000e-04
# Epoch 10/30
# 128/128 [==============================] - 30s 238ms/step - loss: 0.3411 - accuracy: 0.8443 - f1_m: 0.7774 - precision_m: 0.7745 - recall_m: 0.8034 - amex_metric_tensorflow: 0.6697 - val_loss: 0.3743 - val_accuracy: 0.8253 - val_f1_m: 0.7402 - val_precision_m: 0.7935 - val_recall_m: 0.7104 - val_amex_metric_tensorflow: 0.6431 - lr: 1.0000e-04
# Epoch 11/30
# 128/128 [==============================] - 30s 238ms/step - loss: 0.3406 - accuracy: 0.8392 - f1_m: 0.7649 - precision_m: 0.7740 - recall_m: 0.7812 - amex_metric_tensorflow: 0.6870 - val_loss: 0.3843 - val_accuracy: 0.8207 - val_f1_m: 0.7288 - val_precision_m: 0.7970 - val_recall_m: 0.6909 - val_amex_metric_tensorflow: 0.6390 - lr: 1.0000e-04
# Processing: File With 4 Statements
# C:\Users\Grant\anaconda3\lib\site-packages\sklearn\utils\extmath.py:847: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Grant\anaconda3\lib\site-packages\sklearn\utils\extmath.py:689: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = op(x, *args, **kwargs)
# WARNING:tensorflow:Layer lstm_9 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_10 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_11 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 104/104 [==============================] - 44s 393ms/step - loss: 0.5398 - accuracy: 0.7327 - f1_m: 0.5608 - precision_m: 0.5756 - recall_m: 0.5867 - amex_metric_tensorflow: nan - val_loss: 0.5097 - val_accuracy: 0.7717 - val_f1_m: 0.7383 - val_precision_m: 0.6976 - val_recall_m: 0.7966 - val_amex_metric_tensorflow: 0.5481 - lr: 1.0000e-04
# Epoch 2/30
# 104/104 [==============================] - 22s 215ms/step - loss: 0.4391 - accuracy: 0.7900 - f1_m: 0.7391 - precision_m: 0.7393 - recall_m: 0.7671 - amex_metric_tensorflow: nan - val_loss: 0.4269 - val_accuracy: 0.7880 - val_f1_m: 0.7468 - val_precision_m: 0.7331 - val_recall_m: 0.7745 - val_amex_metric_tensorflow: 0.5712 - lr: 1.0000e-04
# Epoch 3/30
# 104/104 [==============================] - 22s 215ms/step - loss: 0.4055 - accuracy: 0.8073 - f1_m: 0.7614 - precision_m: 0.7594 - recall_m: 0.7850 - amex_metric_tensorflow: 0.6210 - val_loss: 0.4341 - val_accuracy: 0.7859 - val_f1_m: 0.7087 - val_precision_m: 0.7911 - val_recall_m: 0.6542 - val_amex_metric_tensorflow: 0.5757 - lr: 1.0000e-04
# Epoch 4/30
# 104/104 [==============================] - 22s 215ms/step - loss: 0.3852 - accuracy: 0.8127 - f1_m: 0.7636 - precision_m: 0.7745 - recall_m: 0.7739 - amex_metric_tensorflow: nan - val_loss: 0.4300 - val_accuracy: 0.7894 - val_f1_m: 0.7537 - val_precision_m: 0.7202 - val_recall_m: 0.8054 - val_amex_metric_tensorflow: 0.5708 - lr: 1.0000e-04
# Epoch 5/30
# 104/104 [==============================] - 22s 216ms/step - loss: 0.3706 - accuracy: 0.8179 - f1_m: 0.7735 - precision_m: 0.7788 - recall_m: 0.7911 - amex_metric_tensorflow: 0.6722 - val_loss: 0.4337 - val_accuracy: 0.7943 - val_f1_m: 0.7440 - val_precision_m: 0.7566 - val_recall_m: 0.7478 - val_amex_metric_tensorflow: 0.5683 - lr: 1.0000e-04
# Epoch 6/30
# 104/104 [==============================] - 22s 215ms/step - loss: 0.3520 - accuracy: 0.8236 - f1_m: 0.7748 - precision_m: 0.8021 - recall_m: 0.7717 - amex_metric_tensorflow: 0.6889 - val_loss: 0.4534 - val_accuracy: 0.7760 - val_f1_m: 0.6977 - val_precision_m: 0.7814 - val_recall_m: 0.6434 - val_amex_metric_tensorflow: 0.5660 - lr: 1.0000e-04
# Epoch 7/30
# 104/104 [==============================] - 22s 215ms/step - loss: 0.3480 - accuracy: 0.8412 - f1_m: 0.8006 - precision_m: 0.8117 - recall_m: 0.8117 - amex_metric_tensorflow: 0.7029 - val_loss: 0.4591 - val_accuracy: 0.7739 - val_f1_m: 0.6906 - val_precision_m: 0.8011 - val_recall_m: 0.6218 - val_amex_metric_tensorflow: 0.5794 - lr: 1.0000e-04
# Epoch 8/30
# 104/104 [==============================] - 39s 374ms/step - loss: 0.3126 - accuracy: 0.8509 - f1_m: 0.8156 - precision_m: 0.8226 - recall_m: 0.8313 - amex_metric_tensorflow: 0.7264 - val_loss: 0.4476 - val_accuracy: 0.7731 - val_f1_m: 0.7157 - val_precision_m: 0.7343 - val_recall_m: 0.7102 - val_amex_metric_tensorflow: 0.5475 - lr: 1.0000e-04
# Epoch 9/30
# 104/104 [==============================] - 38s 371ms/step - loss: 0.3066 - accuracy: 0.8721 - f1_m: 0.8400 - precision_m: 0.8389 - recall_m: 0.8581 - amex_metric_tensorflow: 0.7602 - val_loss: 0.5078 - val_accuracy: 0.7633 - val_f1_m: 0.6995 - val_precision_m: 0.7390 - val_recall_m: 0.6775 - val_amex_metric_tensorflow: 0.5444 - lr: 1.0000e-04
# Epoch 10/30
# 104/104 [==============================] - 39s 375ms/step - loss: 0.2540 - accuracy: 0.8879 - f1_m: 0.8573 - precision_m: 0.8556 - recall_m: 0.8740 - amex_metric_tensorflow: 0.8089 - val_loss: 0.6606 - val_accuracy: 0.7583 - val_f1_m: 0.6845 - val_precision_m: 0.7454 - val_recall_m: 0.6431 - val_amex_metric_tensorflow: 0.5098 - lr: 1.0000e-04
# Processing: File With 5 Statements
# WARNING:tensorflow:Layer lstm_12 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_13 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_14 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 104/104 [==============================] - 47s 421ms/step - loss: 0.5074 - accuracy: 0.7202 - f1_m: 0.5453 - precision_m: 0.6147 - recall_m: 0.5730 - amex_metric_tensorflow: 0.5379 - val_loss: 0.4053 - val_accuracy: 0.7949 - val_f1_m: 0.7271 - val_precision_m: 0.7844 - val_recall_m: 0.6981 - val_amex_metric_tensorflow: 0.5913 - lr: 1.0000e-04
# Epoch 2/30
# 104/104 [==============================] - 27s 255ms/step - loss: 0.3968 - accuracy: 0.8060 - f1_m: 0.7253 - precision_m: 0.7679 - recall_m: 0.7250 - amex_metric_tensorflow: 0.6260 - val_loss: 0.4000 - val_accuracy: 0.7992 - val_f1_m: 0.7134 - val_precision_m: 0.8347 - val_recall_m: 0.6390 - val_amex_metric_tensorflow: 0.6274 - lr: 1.0000e-04
# Epoch 3/30
# 104/104 [==============================] - 27s 256ms/step - loss: 0.3845 - accuracy: 0.8175 - f1_m: 0.7495 - precision_m: 0.7822 - recall_m: 0.7485 - amex_metric_tensorflow: 0.6608 - val_loss: 0.4060 - val_accuracy: 0.8048 - val_f1_m: 0.7895 - val_precision_m: 0.6933 - val_recall_m: 0.9344 - val_amex_metric_tensorflow: 0.6540 - lr: 1.0000e-04
# Epoch 4/30
# 104/104 [==============================] - 27s 258ms/step - loss: 0.3710 - accuracy: 0.8257 - f1_m: 0.7560 - precision_m: 0.7772 - recall_m: 0.7668 - amex_metric_tensorflow: nan - val_loss: 0.4068 - val_accuracy: 0.7850 - val_f1_m: 0.6733 - val_precision_m: 0.8609 - val_recall_m: 0.5707 - val_amex_metric_tensorflow: 0.6256 - lr: 1.0000e-04
# Epoch 5/30
# 104/104 [==============================] - 27s 258ms/step - loss: 0.3630 - accuracy: 0.8224 - f1_m: 0.7566 - precision_m: 0.7963 - recall_m: 0.7566 - amex_metric_tensorflow: 0.6711 - val_loss: 0.4007 - val_accuracy: 0.8119 - val_f1_m: 0.7391 - val_precision_m: 0.8249 - val_recall_m: 0.6845 - val_amex_metric_tensorflow: 0.6481 - lr: 1.0000e-04
# Epoch 6/30
# 104/104 [==============================] - 27s 256ms/step - loss: 0.3438 - accuracy: 0.8366 - f1_m: 0.7680 - precision_m: 0.7979 - recall_m: 0.7581 - amex_metric_tensorflow: nan - val_loss: 0.3837 - val_accuracy: 0.8168 - val_f1_m: 0.7662 - val_precision_m: 0.7849 - val_recall_m: 0.7655 - val_amex_metric_tensorflow: 0.6493 - lr: 1.0000e-04
# Epoch 7/30
# 104/104 [==============================] - 27s 256ms/step - loss: 0.3437 - accuracy: 0.8400 - f1_m: 0.7880 - precision_m: 0.8086 - recall_m: 0.7923 - amex_metric_tensorflow: 0.6971 - val_loss: 0.3998 - val_accuracy: 0.8069 - val_f1_m: 0.7284 - val_precision_m: 0.8283 - val_recall_m: 0.6669 - val_amex_metric_tensorflow: 0.6509 - lr: 1.0000e-04
# Epoch 8/30
# 104/104 [==============================] - 27s 256ms/step - loss: 0.3375 - accuracy: 0.8436 - f1_m: 0.7812 - precision_m: 0.8030 - recall_m: 0.7810 - amex_metric_tensorflow: nan - val_loss: 0.3767 - val_accuracy: 0.8175 - val_f1_m: 0.7486 - val_precision_m: 0.8276 - val_recall_m: 0.6987 - val_amex_metric_tensorflow: 0.6441 - lr: 1.0000e-04
# Epoch 9/30
# 104/104 [==============================] - 27s 258ms/step - loss: 0.3182 - accuracy: 0.8536 - f1_m: 0.7959 - precision_m: 0.8190 - recall_m: 0.7907 - amex_metric_tensorflow: nan - val_loss: 0.3838 - val_accuracy: 0.8310 - val_f1_m: 0.7994 - val_precision_m: 0.7563 - val_recall_m: 0.8615 - val_amex_metric_tensorflow: 0.6329 - lr: 1.0000e-04
# Epoch 10/30
# 104/104 [==============================] - 27s 258ms/step - loss: 0.3210 - accuracy: 0.8451 - f1_m: 0.7918 - precision_m: 0.8179 - recall_m: 0.7885 - amex_metric_tensorflow: 0.7505 - val_loss: 0.4140 - val_accuracy: 0.8161 - val_f1_m: 0.7495 - val_precision_m: 0.8140 - val_recall_m: 0.7093 - val_amex_metric_tensorflow: 0.6323 - lr: 1.0000e-04
# Epoch 11/30
# 104/104 [==============================] - 27s 257ms/step - loss: 0.2981 - accuracy: 0.8590 - f1_m: 0.8104 - precision_m: 0.8377 - recall_m: 0.8034 - amex_metric_tensorflow: 0.7377 - val_loss: 0.4588 - val_accuracy: 0.8303 - val_f1_m: 0.7928 - val_precision_m: 0.7757 - val_recall_m: 0.8254 - val_amex_metric_tensorflow: 0.6289 - lr: 1.0000e-04
# Epoch 12/30
# 104/104 [==============================] - 27s 256ms/step - loss: 0.2963 - accuracy: 0.8651 - f1_m: 0.8107 - precision_m: 0.8436 - recall_m: 0.8008 - amex_metric_tensorflow: 0.7776 - val_loss: 0.4665 - val_accuracy: 0.8062 - val_f1_m: 0.7332 - val_precision_m: 0.8143 - val_recall_m: 0.6823 - val_amex_metric_tensorflow: 0.6109 - lr: 1.0000e-04
# Epoch 13/30
# 104/104 [==============================] - 27s 258ms/step - loss: 0.2870 - accuracy: 0.8666 - f1_m: 0.8105 - precision_m: 0.8440 - recall_m: 0.8030 - amex_metric_tensorflow: 0.7861 - val_loss: 0.4993 - val_accuracy: 0.8091 - val_f1_m: 0.7370 - val_precision_m: 0.8187 - val_recall_m: 0.6873 - val_amex_metric_tensorflow: 0.6241 - lr: 1.0000e-04
# Epoch 14/30
# 104/104 [==============================] - 27s 258ms/step - loss: 0.2781 - accuracy: 0.8784 - f1_m: 0.8300 - precision_m: 0.8692 - recall_m: 0.8128 - amex_metric_tensorflow: nan - val_loss: 0.5495 - val_accuracy: 0.8161 - val_f1_m: 0.7715 - val_precision_m: 0.7630 - val_recall_m: 0.7948 - val_amex_metric_tensorflow: 0.6012 - lr: 1.0000e-04
# Processing: File With 6 Statements
# WARNING:tensorflow:Layer lstm_15 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_16 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_17 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 122/122 [==============================] - 76s 597ms/step - loss: 0.6861 - accuracy: 0.6721 - f1_m: 0.4527 - precision_m: 0.5275 - recall_m: 0.5093 - amex_metric_tensorflow: 0.4925 - val_loss: 0.8093 - val_accuracy: 0.4916 - val_f1_m: 0.5992 - val_precision_m: 0.4327 - val_recall_m: 0.9985 - val_amex_metric_tensorflow: 0.6015 - lr: 1.0000e-04
# Epoch 2/30
# 122/122 [==============================] - 48s 395ms/step - loss: 0.4394 - accuracy: 0.7853 - f1_m: 0.7061 - precision_m: 0.7442 - recall_m: 0.7302 - amex_metric_tensorflow: 0.5943 - val_loss: 0.4394 - val_accuracy: 0.7854 - val_f1_m: 0.7677 - val_precision_m: 0.6614 - val_recall_m: 0.9288 - val_amex_metric_tensorflow: 0.6352 - lr: 1.0000e-04
# Epoch 3/30
# 122/122 [==============================] - 49s 400ms/step - loss: 0.4073 - accuracy: 0.7987 - f1_m: 0.7336 - precision_m: 0.7581 - recall_m: 0.7518 - amex_metric_tensorflow: 0.6211 - val_loss: 0.5603 - val_accuracy: 0.7476 - val_f1_m: 0.5189 - val_precision_m: 0.9386 - val_recall_m: 0.3688 - val_amex_metric_tensorflow: 0.6520 - lr: 1.0000e-04
# Epoch 4/30
# 122/122 [==============================] - 49s 406ms/step - loss: 0.4205 - accuracy: 0.8005 - f1_m: 0.7313 - precision_m: 0.7770 - recall_m: 0.7497 - amex_metric_tensorflow: 0.6269 - val_loss: 0.3552 - val_accuracy: 0.8339 - val_f1_m: 0.7684 - val_precision_m: 0.8292 - val_recall_m: 0.7284 - val_amex_metric_tensorflow: 0.6546 - lr: 1.0000e-04
# Epoch 5/30
# 122/122 [==============================] - 51s 416ms/step - loss: 0.3828 - accuracy: 0.8200 - f1_m: 0.7621 - precision_m: 0.7767 - recall_m: 0.7761 - amex_metric_tensorflow: 0.6560 - val_loss: 0.3754 - val_accuracy: 0.8435 - val_f1_m: 0.7925 - val_precision_m: 0.8049 - val_recall_m: 0.7904 - val_amex_metric_tensorflow: 0.6665 - lr: 1.0000e-04
# Epoch 6/30
# 122/122 [==============================] - 51s 415ms/step - loss: 0.3781 - accuracy: 0.8182 - f1_m: 0.7566 - precision_m: 0.7844 - recall_m: 0.7682 - amex_metric_tensorflow: 0.6614 - val_loss: 0.3482 - val_accuracy: 0.8459 - val_f1_m: 0.8006 - val_precision_m: 0.7927 - val_recall_m: 0.8179 - val_amex_metric_tensorflow: 0.6691 - lr: 1.0000e-04
# Epoch 7/30
# 122/122 [==============================] - 51s 416ms/step - loss: 0.3846 - accuracy: 0.8220 - f1_m: 0.7537 - precision_m: 0.7945 - recall_m: 0.7629 - amex_metric_tensorflow: 0.6516 - val_loss: 0.3568 - val_accuracy: 0.8369 - val_f1_m: 0.7637 - val_precision_m: 0.8524 - val_recall_m: 0.7051 - val_amex_metric_tensorflow: 0.6674 - lr: 1.0000e-04
# Epoch 8/30
# 122/122 [==============================] - 51s 415ms/step - loss: 0.3622 - accuracy: 0.8354 - f1_m: 0.7748 - precision_m: 0.7934 - recall_m: 0.7856 - amex_metric_tensorflow: 0.6691 - val_loss: 0.3499 - val_accuracy: 0.8471 - val_f1_m: 0.7921 - val_precision_m: 0.8307 - val_recall_m: 0.7691 - val_amex_metric_tensorflow: 0.6673 - lr: 1.0000e-04
# Epoch 9/30
# 122/122 [==============================] - 50s 413ms/step - loss: 0.3535 - accuracy: 0.8287 - f1_m: 0.7728 - precision_m: 0.7863 - recall_m: 0.7836 - amex_metric_tensorflow: 0.6891 - val_loss: 0.3877 - val_accuracy: 0.8303 - val_f1_m: 0.7455 - val_precision_m: 0.8640 - val_recall_m: 0.6676 - val_amex_metric_tensorflow: 0.6560 - lr: 1.0000e-04
# Epoch 10/30
# 122/122 [==============================] - 51s 415ms/step - loss: 0.3627 - accuracy: 0.8249 - f1_m: 0.7605 - precision_m: 0.7913 - recall_m: 0.7586 - amex_metric_tensorflow: 0.6808 - val_loss: 0.3733 - val_accuracy: 0.8429 - val_f1_m: 0.7924 - val_precision_m: 0.8044 - val_recall_m: 0.7909 - val_amex_metric_tensorflow: 0.6677 - lr: 1.0000e-04
# Epoch 11/30
# 122/122 [==============================] - 51s 414ms/step - loss: 0.3593 - accuracy: 0.8279 - f1_m: 0.7683 - precision_m: 0.7853 - recall_m: 0.7857 - amex_metric_tensorflow: 0.6886 - val_loss: 0.3490 - val_accuracy: 0.8357 - val_f1_m: 0.7921 - val_precision_m: 0.7679 - val_recall_m: 0.8325 - val_amex_metric_tensorflow: 0.6602 - lr: 1.0000e-04
# Epoch 12/30
# 122/122 [==============================] - 51s 414ms/step - loss: 0.3488 - accuracy: 0.8367 - f1_m: 0.7770 - precision_m: 0.8020 - recall_m: 0.7824 - amex_metric_tensorflow: 0.6961 - val_loss: 0.3420 - val_accuracy: 0.8453 - val_f1_m: 0.8031 - val_precision_m: 0.7843 - val_recall_m: 0.8343 - val_amex_metric_tensorflow: 0.6758 - lr: 1.0000e-04
# Epoch 13/30
# 122/122 [==============================] - 50s 411ms/step - loss: 0.3470 - accuracy: 0.8331 - f1_m: 0.7675 - precision_m: 0.7997 - recall_m: 0.7721 - amex_metric_tensorflow: 0.6974 - val_loss: 0.3974 - val_accuracy: 0.8070 - val_f1_m: 0.7825 - val_precision_m: 0.6946 - val_recall_m: 0.9107 - val_amex_metric_tensorflow: 0.6467 - lr: 1.0000e-04
# Processing: File With 7 Statements
# C:\Users\Grant\anaconda3\lib\site-packages\sklearn\utils\extmath.py:847: RuntimeWarning: invalid value encountered in true_divide
#   updated_mean = (last_sum + new_sum) / updated_sample_count
# C:\Users\Grant\anaconda3\lib\site-packages\sklearn\utils\extmath.py:689: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   result = op(x, *args, **kwargs)
# WARNING:tensorflow:Layer lstm_18 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_19 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_20 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 115/115 [==============================] - 75s 616ms/step - loss: 0.4532 - accuracy: 0.7830 - f1_m: 0.7173 - precision_m: 0.6841 - recall_m: 0.7753 - amex_metric_tensorflow: 0.5529 - val_loss: 0.4198 - val_accuracy: 0.8029 - val_f1_m: 0.7493 - val_precision_m: 0.7810 - val_recall_m: 0.7348 - val_amex_metric_tensorflow: 0.6024 - lr: 1.0000e-04
# Epoch 2/30
# 115/115 [==============================] - 47s 406ms/step - loss: 0.3692 - accuracy: 0.8288 - f1_m: 0.7973 - precision_m: 0.7829 - recall_m: 0.8303 - amex_metric_tensorflow: 0.6540 - val_loss: 0.3919 - val_accuracy: 0.8144 - val_f1_m: 0.7784 - val_precision_m: 0.7340 - val_recall_m: 0.8480 - val_amex_metric_tensorflow: 0.6122 - lr: 1.0000e-04
# Epoch 3/30
# 115/115 [==============================] - 46s 400ms/step - loss: 0.3345 - accuracy: 0.8449 - f1_m: 0.8115 - precision_m: 0.8028 - recall_m: 0.8341 - amex_metric_tensorflow: 0.6951 - val_loss: 0.3884 - val_accuracy: 0.8252 - val_f1_m: 0.7637 - val_precision_m: 0.7807 - val_recall_m: 0.7614 - val_amex_metric_tensorflow: 0.6497 - lr: 1.0000e-04
# Epoch 4/30
# 115/115 [==============================] - 46s 404ms/step - loss: 0.2979 - accuracy: 0.8680 - f1_m: 0.8396 - precision_m: 0.8299 - recall_m: 0.8621 - amex_metric_tensorflow: 0.7566 - val_loss: 0.3927 - val_accuracy: 0.8144 - val_f1_m: 0.7578 - val_precision_m: 0.7522 - val_recall_m: 0.7814 - val_amex_metric_tensorflow: 0.6212 - lr: 1.0000e-04
# Epoch 5/30
# 115/115 [==============================] - 46s 402ms/step - loss: 0.2639 - accuracy: 0.8792 - f1_m: 0.8500 - precision_m: 0.8512 - recall_m: 0.8632 - amex_metric_tensorflow: 0.7854 - val_loss: 0.4851 - val_accuracy: 0.7997 - val_f1_m: 0.7737 - val_precision_m: 0.7048 - val_recall_m: 0.8769 - val_amex_metric_tensorflow: 0.6067 - lr: 1.0000e-04
# Epoch 6/30
# 115/115 [==============================] - 46s 400ms/step - loss: 0.2280 - accuracy: 0.9128 - f1_m: 0.8907 - precision_m: 0.8882 - recall_m: 0.9046 - amex_metric_tensorflow: 0.8393 - val_loss: 0.5544 - val_accuracy: 0.8055 - val_f1_m: 0.7591 - val_precision_m: 0.7631 - val_recall_m: 0.7693 - val_amex_metric_tensorflow: 0.6094 - lr: 1.0000e-04
# Epoch 7/30
# 115/115 [==============================] - 46s 401ms/step - loss: 0.1504 - accuracy: 0.9376 - f1_m: 0.9211 - precision_m: 0.9258 - recall_m: 0.9216 - amex_metric_tensorflow: 0.9015 - val_loss: 0.7113 - val_accuracy: 0.8042 - val_f1_m: 0.7356 - val_precision_m: 0.7546 - val_recall_m: 0.7304 - val_amex_metric_tensorflow: 0.6232 - lr: 1.0000e-04
# Epoch 8/30
# 115/115 [==============================] - 67s 584ms/step - loss: 0.1052 - accuracy: 0.9605 - f1_m: 0.9499 - precision_m: 0.9517 - recall_m: 0.9526 - amex_metric_tensorflow: 0.9249 - val_loss: 0.7090 - val_accuracy: 0.7940 - val_f1_m: 0.7229 - val_precision_m: 0.7495 - val_recall_m: 0.7136 - val_amex_metric_tensorflow: 0.5609 - lr: 1.0000e-04
# Processing: File With 8 Statements
# WARNING:tensorflow:Layer lstm_21 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_22 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_23 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 135/135 [==============================] - 97s 695ms/step - loss: 0.4796 - accuracy: 0.7631 - f1_m: 0.7220 - precision_m: 0.7103 - recall_m: 0.7687 - amex_metric_tensorflow: 0.5484 - val_loss: 0.4387 - val_accuracy: 0.7768 - val_f1_m: 0.6991 - val_precision_m: 0.8864 - val_recall_m: 0.5888 - val_amex_metric_tensorflow: 0.6367 - lr: 1.0000e-04
# Epoch 2/30
# 135/135 [==============================] - 93s 689ms/step - loss: 0.4233 - accuracy: 0.8007 - f1_m: 0.7773 - precision_m: 0.7653 - recall_m: 0.8182 - amex_metric_tensorflow: 0.6364 - val_loss: 0.3868 - val_accuracy: 0.8397 - val_f1_m: 0.8267 - val_precision_m: 0.7960 - val_recall_m: 0.8676 - val_amex_metric_tensorflow: 0.6224 - lr: 1.0000e-04
# Epoch 3/30
# 135/135 [==============================] - 68s 503ms/step - loss: 0.3757 - accuracy: 0.8269 - f1_m: 0.7981 - precision_m: 0.8005 - recall_m: 0.8158 - amex_metric_tensorflow: 0.6683 - val_loss: 0.3941 - val_accuracy: 0.8397 - val_f1_m: 0.8227 - val_precision_m: 0.8154 - val_recall_m: 0.8374 - val_amex_metric_tensorflow: 0.6366 - lr: 1.0000e-04
# Epoch 4/30
# 135/135 [==============================] - 93s 689ms/step - loss: 0.3596 - accuracy: 0.8400 - f1_m: 0.8167 - precision_m: 0.8104 - recall_m: 0.8362 - amex_metric_tensorflow: 0.6905 - val_loss: 0.4025 - val_accuracy: 0.8369 - val_f1_m: 0.8241 - val_precision_m: 0.7894 - val_recall_m: 0.8701 - val_amex_metric_tensorflow: 0.6138 - lr: 1.0000e-04
# Epoch 5/30
# 135/135 [==============================] - 92s 685ms/step - loss: 0.3835 - accuracy: 0.8376 - f1_m: 0.8100 - precision_m: 0.8161 - recall_m: 0.8250 - amex_metric_tensorflow: 0.7054 - val_loss: 0.4090 - val_accuracy: 0.8348 - val_f1_m: 0.8085 - val_precision_m: 0.8414 - val_recall_m: 0.7846 - val_amex_metric_tensorflow: 0.6094 - lr: 1.0000e-04
# Epoch 6/30
# 135/135 [==============================] - 93s 688ms/step - loss: 0.3208 - accuracy: 0.8571 - f1_m: 0.8331 - precision_m: 0.8413 - recall_m: 0.8375 - amex_metric_tensorflow: 0.7441 - val_loss: 0.4292 - val_accuracy: 0.8229 - val_f1_m: 0.7937 - val_precision_m: 0.8210 - val_recall_m: 0.7772 - val_amex_metric_tensorflow: 0.6047 - lr: 1.0000e-04
# Epoch 7/30
# 135/135 [==============================] - 92s 685ms/step - loss: 0.2846 - accuracy: 0.8767 - f1_m: 0.8565 - precision_m: 0.8653 - recall_m: 0.8615 - amex_metric_tensorflow: 0.7769 - val_loss: 0.5659 - val_accuracy: 0.8212 - val_f1_m: 0.8061 - val_precision_m: 0.7752 - val_recall_m: 0.8497 - val_amex_metric_tensorflow: 0.5971 - lr: 1.0000e-04
# Processing: File With 9 Statements
# WARNING:tensorflow:Layer lstm_24 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_25 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_26 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 142/142 [==============================] - 108s 737ms/step - loss: 0.4454 - accuracy: 0.7827 - f1_m: 0.7350 - precision_m: 0.7355 - recall_m: 0.7713 - amex_metric_tensorflow: 0.5761 - val_loss: 0.3856 - val_accuracy: 0.8146 - val_f1_m: 0.8024 - val_precision_m: 0.7711 - val_recall_m: 0.8511 - val_amex_metric_tensorflow: 0.6429 - lr: 1.0000e-04
# Epoch 2/30
# 142/142 [==============================] - 79s 555ms/step - loss: 0.3801 - accuracy: 0.8341 - f1_m: 0.8149 - precision_m: 0.8014 - recall_m: 0.8463 - amex_metric_tensorflow: 0.6568 - val_loss: 0.3758 - val_accuracy: 0.8182 - val_f1_m: 0.8102 - val_precision_m: 0.7585 - val_recall_m: 0.8813 - val_amex_metric_tensorflow: 0.6784 - lr: 1.0000e-04
# Epoch 3/30
# 142/142 [==============================] - 79s 555ms/step - loss: 0.3800 - accuracy: 0.8315 - f1_m: 0.8096 - precision_m: 0.7985 - recall_m: 0.8451 - amex_metric_tensorflow: 0.6493 - val_loss: 0.3833 - val_accuracy: 0.8187 - val_f1_m: 0.7868 - val_precision_m: 0.8292 - val_recall_m: 0.7632 - val_amex_metric_tensorflow: 0.6709 - lr: 1.0000e-04
# Epoch 4/30
# 142/142 [==============================] - 79s 554ms/step - loss: 0.3388 - accuracy: 0.8436 - f1_m: 0.8156 - precision_m: 0.8120 - recall_m: 0.8340 - amex_metric_tensorflow: 0.7056 - val_loss: 0.3685 - val_accuracy: 0.8301 - val_f1_m: 0.8015 - val_precision_m: 0.8311 - val_recall_m: 0.7879 - val_amex_metric_tensorflow: 0.6693 - lr: 1.0000e-04
# Epoch 5/30
# 142/142 [==============================] - 79s 555ms/step - loss: 0.3307 - accuracy: 0.8512 - f1_m: 0.8239 - precision_m: 0.8171 - recall_m: 0.8456 - amex_metric_tensorflow: nan - val_loss: 0.3627 - val_accuracy: 0.8306 - val_f1_m: 0.8047 - val_precision_m: 0.8224 - val_recall_m: 0.8025 - val_amex_metric_tensorflow: 0.6741 - lr: 1.0000e-04
# Epoch 6/30
# 142/142 [==============================] - 79s 555ms/step - loss: 0.3170 - accuracy: 0.8543 - f1_m: 0.8282 - precision_m: 0.8282 - recall_m: 0.8461 - amex_metric_tensorflow: nan - val_loss: 0.4012 - val_accuracy: 0.8213 - val_f1_m: 0.7857 - val_precision_m: 0.8455 - val_recall_m: 0.7471 - val_amex_metric_tensorflow: 0.6534 - lr: 1.0000e-04
# Epoch 7/30
# 142/142 [==============================] - 79s 555ms/step - loss: 0.3042 - accuracy: 0.8609 - f1_m: 0.8410 - precision_m: 0.8422 - recall_m: 0.8559 - amex_metric_tensorflow: nan - val_loss: 0.3791 - val_accuracy: 0.8264 - val_f1_m: 0.8105 - val_precision_m: 0.7898 - val_recall_m: 0.8424 - val_amex_metric_tensorflow: 0.6573 - lr: 1.0000e-04
# Epoch 8/30
# 142/142 [==============================] - 103s 730ms/step - loss: 0.3096 - accuracy: 0.8600 - f1_m: 0.8368 - precision_m: 0.8346 - recall_m: 0.8564 - amex_metric_tensorflow: nan - val_loss: 0.4018 - val_accuracy: 0.8249 - val_f1_m: 0.7921 - val_precision_m: 0.8409 - val_recall_m: 0.7614 - val_amex_metric_tensorflow: 0.6405 - lr: 1.0000e-04
# Epoch 9/30
# 142/142 [==============================] - 104s 732ms/step - loss: 0.2900 - accuracy: 0.8678 - f1_m: 0.8495 - precision_m: 0.8554 - recall_m: 0.8582 - amex_metric_tensorflow: 0.7711 - val_loss: 0.5159 - val_accuracy: 0.8125 - val_f1_m: 0.7903 - val_precision_m: 0.7855 - val_recall_m: 0.8072 - val_amex_metric_tensorflow: 0.6173 - lr: 1.0000e-04
# Epoch 10/30
# 142/142 [==============================] - 104s 733ms/step - loss: 0.2748 - accuracy: 0.8757 - f1_m: 0.8592 - precision_m: 0.8621 - recall_m: 0.8686 - amex_metric_tensorflow: 0.7850 - val_loss: 0.4484 - val_accuracy: 0.8301 - val_f1_m: 0.8102 - val_precision_m: 0.8033 - val_recall_m: 0.8279 - val_amex_metric_tensorflow: 0.6143 - lr: 1.0000e-04
# Processing: File With 10 Statements
# WARNING:tensorflow:Layer lstm_27 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_28 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_29 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 148/148 [==============================] - 119s 780ms/step - loss: 0.4344 - accuracy: 0.8016 - f1_m: 0.7905 - precision_m: 0.7651 - recall_m: 0.8423 - amex_metric_tensorflow: 0.5891 - val_loss: 0.3902 - val_accuracy: 0.8241 - val_f1_m: 0.7987 - val_precision_m: 0.7880 - val_recall_m: 0.8248 - val_amex_metric_tensorflow: 0.6219 - lr: 1.0000e-04
# Epoch 2/30
# 148/148 [==============================] - 90s 607ms/step - loss: 0.3563 - accuracy: 0.8362 - f1_m: 0.8252 - precision_m: 0.8041 - recall_m: 0.8573 - amex_metric_tensorflow: 0.6777 - val_loss: 0.3956 - val_accuracy: 0.8319 - val_f1_m: 0.8052 - val_precision_m: 0.8169 - val_recall_m: 0.8091 - val_amex_metric_tensorflow: 0.6411 - lr: 1.0000e-04
# Epoch 3/30
# 148/148 [==============================] - 90s 609ms/step - loss: 0.3199 - accuracy: 0.8548 - f1_m: 0.8433 - precision_m: 0.8298 - recall_m: 0.8699 - amex_metric_tensorflow: 0.7133 - val_loss: 0.3852 - val_accuracy: 0.8226 - val_f1_m: 0.8049 - val_precision_m: 0.7643 - val_recall_m: 0.8648 - val_amex_metric_tensorflow: 0.6427 - lr: 1.0000e-04
# Epoch 4/30
# 148/148 [==============================] - 90s 608ms/step - loss: 0.2943 - accuracy: 0.8698 - f1_m: 0.8592 - precision_m: 0.8454 - recall_m: 0.8865 - amex_metric_tensorflow: 0.7603 - val_loss: 0.5200 - val_accuracy: 0.8236 - val_f1_m: 0.7954 - val_precision_m: 0.8022 - val_recall_m: 0.8044 - val_amex_metric_tensorflow: 0.6331 - lr: 1.0000e-04
# Epoch 5/30
# 148/148 [==============================] - 90s 609ms/step - loss: 0.2413 - accuracy: 0.8992 - f1_m: 0.8902 - precision_m: 0.8809 - recall_m: 0.9077 - amex_metric_tensorflow: 0.8086 - val_loss: 0.4361 - val_accuracy: 0.8172 - val_f1_m: 0.7823 - val_precision_m: 0.8039 - val_recall_m: 0.7775 - val_amex_metric_tensorflow: 0.6252 - lr: 1.0000e-04
# Epoch 6/30
# 148/148 [==============================] - 115s 778ms/step - loss: 0.1908 - accuracy: 0.9195 - f1_m: 0.9138 - precision_m: 0.9071 - recall_m: 0.9255 - amex_metric_tensorflow: 0.8478 - val_loss: 0.5265 - val_accuracy: 0.8034 - val_f1_m: 0.7867 - val_precision_m: 0.7323 - val_recall_m: 0.8658 - val_amex_metric_tensorflow: 0.5894 - lr: 1.0000e-04
# Epoch 7/30
# 148/148 [==============================] - 115s 781ms/step - loss: 0.1547 - accuracy: 0.9387 - f1_m: 0.9324 - precision_m: 0.9316 - recall_m: 0.9394 - amex_metric_tensorflow: 0.8853 - val_loss: 0.5709 - val_accuracy: 0.7871 - val_f1_m: 0.7475 - val_precision_m: 0.7675 - val_recall_m: 0.7450 - val_amex_metric_tensorflow: 0.5832 - lr: 1.0000e-04
# Processing: File With 11 Statements
# WARNING:tensorflow:Layer lstm_30 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_31 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_32 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 132/132 [==============================] - 116s 853ms/step - loss: 0.4399 - accuracy: 0.7988 - f1_m: 0.7572 - precision_m: 0.7297 - recall_m: 0.8112 - amex_metric_tensorflow: 0.5613 - val_loss: 0.3986 - val_accuracy: 0.8187 - val_f1_m: 0.8168 - val_precision_m: 0.7469 - val_recall_m: 0.9157 - val_amex_metric_tensorflow: 0.6089 - lr: 1.0000e-04
# Epoch 2/30
# 132/132 [==============================] - 87s 657ms/step - loss: 0.3648 - accuracy: 0.8381 - f1_m: 0.8179 - precision_m: 0.7903 - recall_m: 0.8640 - amex_metric_tensorflow: 0.6342 - val_loss: 0.3726 - val_accuracy: 0.8281 - val_f1_m: 0.8197 - val_precision_m: 0.7708 - val_recall_m: 0.8884 - val_amex_metric_tensorflow: 0.6567 - lr: 1.0000e-04
# Epoch 3/30
# 132/132 [==============================] - 86s 655ms/step - loss: 0.3330 - accuracy: 0.8582 - f1_m: 0.8348 - precision_m: 0.8246 - recall_m: 0.8582 - amex_metric_tensorflow: 0.6989 - val_loss: 0.3803 - val_accuracy: 0.8315 - val_f1_m: 0.8062 - val_precision_m: 0.8429 - val_recall_m: 0.7852 - val_amex_metric_tensorflow: 0.6494 - lr: 1.0000e-04
# Epoch 4/30
# 132/132 [==============================] - 87s 658ms/step - loss: 0.2857 - accuracy: 0.8799 - f1_m: 0.8579 - precision_m: 0.8410 - recall_m: 0.8873 - amex_metric_tensorflow: nan - val_loss: 0.4503 - val_accuracy: 0.8315 - val_f1_m: 0.8052 - val_precision_m: 0.8347 - val_recall_m: 0.7874 - val_amex_metric_tensorflow: 0.6428 - lr: 1.0000e-04
# Epoch 5/30
# 132/132 [==============================] - 112s 852ms/step - loss: 0.2407 - accuracy: 0.8989 - f1_m: 0.8845 - precision_m: 0.8714 - recall_m: 0.9105 - amex_metric_tensorflow: 0.8149 - val_loss: 0.5783 - val_accuracy: 0.8276 - val_f1_m: 0.8190 - val_precision_m: 0.7742 - val_recall_m: 0.8826 - val_amex_metric_tensorflow: 0.6074 - lr: 1.0000e-04
# Epoch 6/30
# 132/132 [==============================] - 87s 663ms/step - loss: 0.1927 - accuracy: 0.9268 - f1_m: 0.9159 - precision_m: 0.9036 - recall_m: 0.9363 - amex_metric_tensorflow: 0.8567 - val_loss: 0.5686 - val_accuracy: 0.8248 - val_f1_m: 0.8131 - val_precision_m: 0.7801 - val_recall_m: 0.8614 - val_amex_metric_tensorflow: 0.6161 - lr: 1.0000e-04
# Epoch 7/30
# 132/132 [==============================] - 87s 662ms/step - loss: 0.1500 - accuracy: 0.9464 - f1_m: 0.9368 - precision_m: 0.9295 - recall_m: 0.9499 - amex_metric_tensorflow: 0.8884 - val_loss: 0.5107 - val_accuracy: 0.8204 - val_f1_m: 0.7945 - val_precision_m: 0.8061 - val_recall_m: 0.7956 - val_amex_metric_tensorflow: 0.6456 - lr: 1.0000e-04
# Epoch 8/30
# 132/132 [==============================] - 112s 853ms/step - loss: 0.1290 - accuracy: 0.9592 - f1_m: 0.9525 - precision_m: 0.9516 - recall_m: 0.9576 - amex_metric_tensorflow: 0.9120 - val_loss: 0.7560 - val_accuracy: 0.8065 - val_f1_m: 0.7710 - val_precision_m: 0.8107 - val_recall_m: 0.7454 - val_amex_metric_tensorflow: 0.6009 - lr: 1.0000e-04
# Processing: File With 12 Statements
# WARNING:tensorflow:Layer lstm_33 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_34 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# WARNING:tensorflow:Layer lstm_35 will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/30
# 234/234 [==============================] - 195s 821ms/step - loss: 0.3782 - accuracy: 0.8279 - f1_m: 0.7709 - precision_m: 0.7539 - recall_m: 0.8168 - amex_metric_tensorflow: 0.6372 - val_loss: 0.3552 - val_accuracy: 0.8340 - val_f1_m: 0.7646 - val_precision_m: 0.8492 - val_recall_m: 0.7096 - val_amex_metric_tensorflow: 0.6788 - lr: 1.0000e-04
# Epoch 2/30
# 234/234 [==============================] - 166s 711ms/step - loss: 0.3161 - accuracy: 0.8582 - f1_m: 0.8093 - precision_m: 0.8096 - recall_m: 0.8250 - amex_metric_tensorflow: nan - val_loss: 0.3798 - val_accuracy: 0.8508 - val_f1_m: 0.7966 - val_precision_m: 0.8442 - val_recall_m: 0.7678 - val_amex_metric_tensorflow: 0.6838 - lr: 1.0000e-04
# Epoch 3/30
# 234/234 [==============================] - 168s 720ms/step - loss: 0.2835 - accuracy: 0.8723 - f1_m: 0.8320 - precision_m: 0.8255 - recall_m: 0.8567 - amex_metric_tensorflow: 0.7458 - val_loss: 0.4582 - val_accuracy: 0.8602 - val_f1_m: 0.8209 - val_precision_m: 0.8146 - val_recall_m: 0.8403 - val_amex_metric_tensorflow: 0.6821 - lr: 1.0000e-04
# Epoch 4/30
# 234/234 [==============================] - 167s 715ms/step - loss: 0.2603 - accuracy: 0.8945 - f1_m: 0.8617 - precision_m: 0.8566 - recall_m: 0.8808 - amex_metric_tensorflow: 0.7988 - val_loss: 0.3393 - val_accuracy: 0.8571 - val_f1_m: 0.8156 - val_precision_m: 0.8122 - val_recall_m: 0.8310 - val_amex_metric_tensorflow: 0.6934 - lr: 1.0000e-04
# Epoch 5/30
# 234/234 [==============================] - 193s 825ms/step - loss: 0.2130 - accuracy: 0.9129 - f1_m: 0.8824 - precision_m: 0.8787 - recall_m: 0.8982 - amex_metric_tensorflow: nan - val_loss: 0.7260 - val_accuracy: 0.8533 - val_f1_m: 0.8130 - val_precision_m: 0.8026 - val_recall_m: 0.8339 - val_amex_metric_tensorflow: 0.6536 - lr: 1.0000e-04
# Epoch 6/30
# 234/234 [==============================] - 193s 823ms/step - loss: 0.2360 - accuracy: 0.9343 - f1_m: 0.9110 - precision_m: 0.9137 - recall_m: 0.9159 - amex_metric_tensorflow: 0.8757 - val_loss: 0.4295 - val_accuracy: 0.8483 - val_f1_m: 0.8092 - val_precision_m: 0.7875 - val_recall_m: 0.8439 - val_amex_metric_tensorflow: 0.6522 - lr: 1.0000e-04
# Epoch 7/30
# 234/234 [==============================] - 228s 978ms/step - loss: 0.1212 - accuracy: 0.9578 - f1_m: 0.9438 - precision_m: 0.9433 - recall_m: 0.9501 - amex_metric_tensorflow: 0.9241 - val_loss: 0.5346 - val_accuracy: 0.8433 - val_f1_m: 0.8068 - val_precision_m: 0.7713 - val_recall_m: 0.8586 - val_amex_metric_tensorflow: 0.6300 - lr: 1.0000e-04
# Epoch 8/30
# 234/234 [==============================] - 236s 1s/step - loss: 0.0996 - accuracy: 0.9700 - f1_m: 0.9605 - precision_m: 0.9625 - recall_m: 0.9628 - amex_metric_tensorflow: 0.9473 - val_loss: 0.5788 - val_accuracy: 0.8437 - val_f1_m: 0.7982 - val_precision_m: 0.7895 - val_recall_m: 0.8199 - val_amex_metric_tensorflow: 0.6291 - lr: 1.0000e-04

# %%
x_train.shape
# Out:
# (3599, 1, 405)

# %%
unique, counts = np.unique(y_train, return_counts=True)

print (np.asarray((unique, counts)).T)
# Out:
# [[   0 2413]
#  [   1 1186]]

# %%
model = load_model("best_model_" + str(number_of_statements) + "_Statments.h5", custom_objects={"f1_m": f1_m, "precision_m": precision_m, "recall_m": recall_m, "amex_metric_tensorflow":amex_metric_tensorflow })
# make predictions
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %%
x_test.shape
# Out:
# (1500, 13, 179)

# %%
x_train.shape
# Out:
# (3599, 1, 229)

# %%
y_train.shape
# Out:
# (3599,)

# %%
for index in range(100,200):
    sample = np.reshape(x_test[index], (1,x_test.shape[1], x_test.shape[2]))

    yhat = model.predict(sample, verbose=0)
    print(yhat, y_test[index])
# Out:
# [[3.2894786e-05]] 0
# [[2.7454513e-05]] 0
# [[2.744323e-05]] 0
# [[0.9999998]] 1
# [[7.422409e-05]] 0
# [[2.5798183e-05]] 0
# [[0.9999996]] 1
# [[7.302886e-05]] 0
# [[4.0247924e-05]] 0
# [[2.4125631e-05]] 0
# [[9.2915274e-05]] 0
# [[8.172402e-05]] 0
# [[3.1855732e-05]] 0
# [[0.9999999]] 1
# [[2.9318388e-05]] 0
# [[2.8906037e-05]] 0
# [[2.6766727e-05]] 0
# [[1.]] 1
# [[2.9638126e-05]] 0
# [[3.607076e-05]] 0
# [[2.9245617e-05]] 0
# [[2.6168345e-05]] 0
# [[1.]] 1
# [[3.9660707e-05]] 0
# [[2.9159033e-05]] 0
# [[3.1829284e-05]] 0
# [[3.746931e-05]] 0
# [[2.726956e-05]] 0
# [[0.00036664]] 0
# [[4.69789e-05]] 0
# [[2.8863971e-05]] 0
# [[3.640556e-05]] 0
# [[0.9999998]] 1
# [[3.5203106e-05]] 0
# [[2.7980534e-05]] 0
# [[3.1185817e-05]] 0
# [[2.8169074e-05]] 0
# [[0.99999964]] 1
# [[0.9999996]] 1
# [[0.99999994]] 1
# [[0.9999999]] 1
# [[0.999998]] 1
# [[0.9999997]] 1
# [[0.99999994]] 1
# [[0.99999994]] 1
# [[0.9999999]] 1
# [[0.9999998]] 1
# [[1.]] 1
# [[0.9999999]] 1
# [[0.99999994]] 1
# [[0.99999994]] 1
# [[0.9999999]] 1
# [[0.9999999]] 1
# [[1.]] 1
# [[1.]] 1
# [[1.]] 1
# [[0.99999994]] 1
# [[0.9999999]] 1
# [[0.9999999]] 1
# [[0.9999997]] 1
# [[0.9999998]] 1
# [[0.9999999]] 1
# [[0.9999999]] 1
# [[0.99999976]] 1
# [[0.99999994]] 1
# [[0.99999994]] 1
# [[0.99999994]] 1
# [[0.9999999]] 1
# [[0.9999999]] 1
# [[0.9999992]] 1
# [[0.99999994]] 1
# [[0.9999999]] 1
# [[0.9999997]] 1
# [[0.99999994]] 1
# [[0.99999994]] 1
# [[0.9999999]] 1
# [[0.99999964]] 1
# [[0.9999998]] 1
# [[0.99999994]] 1
# [[0.9999999]] 1
# [[0.9999999]] 1
# [[0.9999999]] 1
# [[0.99999946]] 1
# [[1.]] 1
# [[1.]] 1
# [[0.9999998]] 1
# [[0.99999964]] 1
# [[0.99999994]] 1
# [[1.]] 1
# [[1.]] 1
# [[0.9999999]] 1
# [[0.9999999]] 1
# [[0.9999999]] 1
# [[0.9999998]] 1
# [[0.9999999]] 1
# [[0.9999999]] 1
# [[0.9999999]] 1
# [[0.9999998]] 1
# [[0.99999994]] 1
# [[0.99999964]] 1

# %%
sample.shape
# Out:
# (1, 13, 179)

# %%
#x_values_to_scale = x_train.columns

#x_values_to_scale= [x for x in x_values_to_scale if x not in category_column]
#scaler = StandardScaler()
#scaler.fit(x_train[x_values_to_scale])
#x_train[x_values_to_scale] = scaler.transform(x_train[x_values_to_scale])
#x_train = x_train.to_numpy()
